# %% [markdown]
# ## Outline
# * Basic elements in html and what they are (html, body, tables, trs, tds, divs)
# * Common attributes in html, such as class and id
# * Concept of selectors relationships (select children or direct child, next sibling, nth child)
# * Parsing HTML(Beautiful Soup)

# %% [markdown]
# ## The result of scraping: HTML data
#
# * GET requests result in HTML; What does this look like?
# * Let's see what is on the NYU Computer Science department website.

# %% [markdown]
# # Requests
#
# * `requests` is a python package that allows you to use Python to interact with the Internet!
# * There are other packages (e.g. `urllib`), but `requests` is the easiest to use.
#
# In fact, to get the UCSD home page is a simple as
# ```
# import requests
# text = requests.get("https://cs.nyu.edu/home/index.html").text
# ```

# %%
import requests
url = "https://cs.nyu.edu/home/index.html"

r = requests.get(url)
    
urlText = r.text

Nchars = 6000
print(urlText[:Nchars]) # Print the first 6000 characters
print("\n\n... " + str(len(urlText)-Nchars) + " additional characters")
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>
# <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>
# <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <title>
#    NYU Computer Science
#   </title>
#   <meta content="The homepage of the Computer Science Department at the Courant Institute of Mathematical Sciences, a part of New York University." name="description"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="/home/dist/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
#   <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <link href="/home/css/main.css?20180702b" rel="stylesheet" type="text/css"/>
#   <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.7.2/animate.min.css" rel="stylesheet"/>
#   <script src="js/vendor/modernizr-2.8.3-respond-1.4.2.min.js">
#   </script>
#   <!-- favicon -->
#   <link href="/home/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/home/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/home/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/home/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/home/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/home/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/home/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/home/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/home/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <link href="/home/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
#   <link href="/home/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/home/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
#   <link href="/home/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/home/manifest.json" rel="manifest"/>
#   <meta content="#ffffff" name="msapplication-TileColor"/>
#   <meta content="/home/ms-icon-144x144.png" name="msapplication-TileImage"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js">
#   </script>
#   <script src="/home/js/preload.js">
#   </script>
#   <script>
#    $(function () {
#             $("#news").load("/dynamic/news/short_list/");
#         });
#         $(function () {
#             $("#events").load("/dynamic/news/event/short_list/");
#         });
#   </script>
#  </head>
#  <body>
#   <div id="topnav">
#    <html>
#  <head>
#  </head>
#  <body>
#   <nav aria-label="Main Menu" class="navbar navbar-default navbar-nyu">
#    <div class="container-fluid">
#     <!-- Brand and toggle get grouped for better mobile display -->
#     <div class="navbar-header">
#      <a href="#main-content" id="skiptomaincontent">
#       Skip to main content
#      </a>
#      <div class="animated slideInDown fast alert alert-danger" id="covid" role="alert" style="margin: 0;">
#       <h2>
#         <a href="https://www.nyu.edu/life/safety-health-wellness/coronavirus-information.html" style="color: #545157;">COVID-19 INFO</a> | Fall 2021 Schedule Information:
#         <a href="https://cs.nyu.edu/home/courses/grad-fall21.html">
#         Graduate
#        </a>
#        /
#        <a href="https://cs.nyu.edu/home/courses/ug-fall21.html">
#         Undergraduate
#        </a>
#       </h2>
#      </div>
#      <div class="navbar-brand" style="position: relative;">
#       <div>
#        <span class="bold">
#         <a href="http://www.nyu.edu">
#          NYU
#         </a>
#        </span>
#        <span class="sep">
#         |
#        </span>
#        <a href="http://cims.nyu.edu">
#         COURANT
#        </a>
#       </div>
#       <div>
#        <img alt="" src="/home/images/torch.png"/>
#       </div>
#       <div>
#        <span class="bold large">
#         <a href="/">
#          Computer Science
#         </a>
#        </span>
#       </div>
#      </div>
#      <button class="navbar-toggle collapsed" data-target="#bs-nyu-navbar-collapse" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#     </div>
#     <!-- Collect the nav links, forms, and other content for toggling -->
#     <div class="collapse navbar-collapse" id="bs-nyu-navbar-collapse">
#      <ul class="nav navbar-nav">
#       <li class="dropdown">
#        <a aria-expanded="false" href="/home/about/" id="nav-about" role="button">
#         About
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/dynamic/news/">
#           News & Events
#          </a>
#         </li>
#         <li>
#          <a href="/home/about/directions.html">
#           Directions
#          </a>
#         </li>
#         <li>
#          <a href="/home/about/contacts.html">
#           Contacts
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li class="dropdown">
#        <a aria-expanded="false" href="/home/research/overview.html" id="nav-research" role="button">
#         Research
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/home/research/overview.html">
#           Overview
#          </a>
#         </li>
#         <li>
#          <a href="/home/research/centers.html">
#           Centers
#          </a>
#         </li>
#         <li>
#          <a href="/dynamic/research/areas/">
#           Areas
#          </a>
#         </li>
#         <li>
#          <a href="/dynamic/people/achievements/">
#           Faculty Achievements
#          </a>
#         </li>
#         <li>
#          <a href="/dynamic/reports/">
#           Theses & Reports
#
#
#
# ... 25159 additional characters

# %%
len(r.text)
# Out:
# 31159

# %% [markdown]
# Wow, that is gross looking!  It is **raw** HTML, which the browser uses to make the viewable site.

# %% [markdown]
# ## What is HTML?
#
# * HTML (HyperText Markup Language) is the most basic building block of the Web. It describes and defines the content of a webpage along with the basic layout of the webpage.
#
# * HTML markup includes special "elements" (tags) such as
#     * `<head>, <title>, <body>, <p>, <div>, <img>`,.....

# %% [markdown]
# 1. `<head>` provides general information about the document, would be the first child of `<html>`
# 2. `<body>` represents the content of an HTML document. There can be only one `<body>` element in a document.
# 3. `<div>` is the generic container for flow content. It has no effect on the content or layout until styled using CSS. As a "pure" container, the element does not inherently represent anything. Instead, it's used to group content so it can be easily styled using the class or id attributes, marking a section of a document as being written in a different language (using the lang attribute), and so on.
# 4. `<table>` tr: table row, th: table header, td: table data
#
#
# See [this tutorial](http://fab.academany.org/2018/labs/fablaboshanghai/students/bob-wu/Fabclass/week2_project_management/HTML.html) for more reference.

# %%
# !cat sample.html
# Out:
# <html>
# 	<head>
# 		<title> Page title </title>
# 	</head>
#
# 	<body>
# 		<h1> This is a heading </h1>
# 		<p> This is a paragraph </p>
#
# 		<p> This is another paragraph </p>
#
# 		<table>
# 			<caption>Alien football stars</caption>
# 			<tr>
# 				<th scope="col">Player</th>
# 				<th scope="col">Gloobles</th>
# 				<th scope="col">Za'taak</th>
# 			</tr>
# 			<tr>
# 				<th scope="row">TR-7</th>
# 				<td>7</td>
# 				<td>4,569</td>
# 			</tr>
# 			<tr>
# 				<th scope="row">Khiresh Odo</th>
# 				<td>7</td>
# 				<td>7,223</td>
# 			</tr>
# 			<tr>
# 				<th scope="row">Mia Oolong</th>
# 				<td>9</td>
# 				<td>6,219</td>
# 			</tr>
# 		</table>
# 	</body>
# </html>

# %%
# open a file via python

import webbrowser
import os
webbrowser.open('file://' + os.path.realpath("sample.html"));

# %% [markdown]
# ##  Images and Hyperlinks
#
# * Tag for a picture (can use a link to the image):
#
# `<img src="HumDum.png" alt="Humbpty Dumpty">`
#
# * Tag for a hyperlink:
#
#   `<a href="https://nyu.edu/">Visit our page!</a>`

# %%
# !cat pic_ref.html
# Out:
# <html>
# 	<head>
# 		<title> Page title </title>
# 	</head>
#
# 	<body>
# 		<h1> My morning starts with:  </h1>
#         <img src="cup.jpg" alt="coffee cup">
# 		<p> You can find gigantic cups
#         <a href="https://www.amazon.com/Allures-Illusions-Worlds-Largest-Gigantic/dp/B00F690L0E?ref_=fsclp_pl_dp_6">HERE!</a>
#         </p>
#
# 		<p> This is another paragraph </p>
# 	</body>
# </html>

# %%
import webbrowser
import os
webbrowser.open('file://' + os.path.realpath("pic_ref.html"));

# the size of the images can be edited.

# %% [markdown]
# ## attribute
# An attribute gives us more information about the tag and what it does. The attributes which affect how CSS works are the CLASS, ID, and the STYLE attributes.

# %% [markdown]
# ## `class` attribute
# The class attribute is often used to point to a class name in a style sheet. It can also be used by a JavaScript to access and manipulate elements with the specific class name.

# %%
# !cat class_attribute.html
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# .city {
#   background-color: tomato;
#   color: white;
#   padding: 10px;
# }
# </style>
# </head>
# <body>
#
# <h2 class="city">London</h2>
# <p>London is the capital of England.</p>
#
# <h2 class="city">Paris</h2>
# <p>Paris is the capital of France.</p>
#
# <h2 class="city">Tokyo</h2>
# <p>Tokyo is the capital of Japan.</p>
#
# </body>
# </html>

# %%
import webbrowser
import os
webbrowser.open('file://' + os.path.realpath("class_attribute.html"));

# %% [markdown]
# ## `id` attribute
# The id attribute specifies a unique id for an HTML element. The value of the id attribute must be unique within the HTML document.
#
# The id attribute is used to point to a specific style declaration in a style sheet. It is also used by JavaScript to access and manipulate the element with the specific id.
#
# The syntax for id is: write a hash character (#), followed by an id name. Then, define the CSS properties within curly braces {}.

# %%
# !cat id_attribute.html
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <style>
# #myHeader {
#   background-color: lightblue;
#   color: black;
#   padding: 40px;
#   text-align: center;
# }
# </style>
# </head>
# <body>
#
# <h1 id="myHeader">My Header</h1>
#
# </body>
# </html>

# %%
import webbrowser
import os
webbrowser.open('file://' + os.path.realpath("id_attribute.html"));

# %% [markdown]
# ## Selectors' Relationship
# - Parent – An element that contains another element
# - Child – An element contained within another element
# - Descendant – Any element inside of an element, even if it is nested within further elements
# - Ascendant – Any element that contains our element, even if it isn't the immediate parent
#
#
# See [this tutorial](https://www.w3schools.com/css/css_combinators.asp) on how to use css combinators

# %% [markdown]
# # Cleaning
#
# * Now we have an idea what the basic structure of the HTML looks like, we can start cleaning it.
#
# * To process it we can use [Beautiful Soup 4](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# **Warning:** BeautifulSoup has changed quite a bit between versions, so make sure you are looking at documentation for the version you are using (4 here).

# %%
url = "https://cs.nyu.edu/home/index.html"
r = requests.get(url)   
urlText = r.text


from bs4 import BeautifulSoup
soup = BeautifulSoup(urlText, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>
# <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]-->
# <!--[if IE 7]>
# <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js lt-ie9" lang="en"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
# <!--<![endif]-->
# <head>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <title>
#    NYU Computer Science
#   </title>
# <meta content="The homepage of the Computer Science Department at the Courant Institute of Mathematical Sciences, a part of New York University." name="description"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/home/dist/css/bootstrap.min.css" rel="stylesheet" type="text/css"/>
# <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/home/css/main.css?20180702b" rel="stylesheet" type="text/css"/>
# <link href="https://cdnjs.cloudflare.com/ajax/libs/animate.css/3.7.2/animate.min.css" rel="stylesheet"/>
# <script src="js/vendor/modernizr-2.8.3-respond-1.4.2.min.js">
# </script>
# <!-- favicon -->
# <link href="/home/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/home/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/home/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/home/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/home/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/home/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/home/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/home/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# <link href="/home/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/home/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>
# <link href="/home/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/home/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>
# <link href="/home/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
# <link href="/home/manifest.json" rel="manifest"/>
# <meta content="#ffffff" name="msapplication-TileColor"/>
# <meta content="/home/ms-icon-144x144.png" name="msapplication-TileImage"/>
# <meta content="#ffffff" name="theme-color"/>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js">
# </script>
# <script src="/home/js/preload.js">
# </script>
# <script>
#    $(function () {
#             $("#news").load("/dynamic/news/short_list/");
#         });
#         $(function () {
#             $("#events").load("/dynamic/news/event/short_list/");
#         });
#   </script>
# </head>
# <body>
# <div id="topnav">
# <html>
# <head>
# </head>
# <body>
# <nav aria-label="Main Menu" class="navbar navbar-default navbar-nyu">
# <div class="container-fluid">
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <a href="#main-content" id="skiptomaincontent">
#       Skip to main content
#      </a>
# <div class="animated slideInDown fast alert alert-danger" id="covid" role="alert" style="margin: 0;">
# <h2>
# <a href="https://www.nyu.edu/life/safety-health-wellness/coronavirus-information.html" style="color: #545157;">COVID-19 INFO</a> | Fall 2021 Schedule Information:
#         <a href="https://cs.nyu.edu/home/courses/grad-fall21.html">
#         Graduate
#        </a>
#        /
#        <a href="https://cs.nyu.edu/home/courses/ug-fall21.html">
#         Undergraduate
#        </a>
# </h2>
# </div>
# <div class="navbar-brand" style="position: relative;">
# <div>
# <span class="bold">
# <a href="http://www.nyu.edu">
#          NYU
#         </a>
# </span>
# <span class="sep">
#         |
#        </span>
# <a href="http://cims.nyu.edu">
#         COURANT
#        </a>
# </div>
# <div>
# <img alt="" src="/home/images/torch.png"/>
# </div>
# <div>
# <span class="bold large">
# <a href="/">
#          Computer Science
#         </a>
# </span>
# </div>
# </div>
# <button class="navbar-toggle collapsed" data-target="#bs-nyu-navbar-collapse" data-toggle="collapse" type="button">
# <span class="sr-only">
#        Toggle navigation
#       </span>
# <span class="icon-bar">
# </span>
# <span class="icon-bar">
# </span>
# <span class="icon-bar">
# </span>
# </button>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="collapse navbar-collapse" id="bs-nyu-navbar-collapse">
# <ul class="nav navbar-nav">
# <li class="dropdown">
# <a aria-expanded="false" href="/home/about/" id="nav-about" role="button">
#         About
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/dynamic/news/">
#           News &amp; Events
#          </a>
# </li>
# <li>
# <a href="/home/about/directions.html">
#           Directions
#          </a>
# </li>
# <li>
# <a href="/home/about/contacts.html">
#           Contacts
#          </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/research/overview.html" id="nav-research" role="button">
#         Research
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/home/research/overview.html">
#           Overview
#          </a>
# </li>
# <li>
# <a href="/home/research/centers.html">
#           Centers
#          </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/">
#           Areas
#          </a>
# </li>
# <li>
# <a href="/dynamic/people/achievements/">
#           Faculty Achievements
#          </a>
# </li>
# <li>
# <a href="/dynamic/reports/">
#           Theses &amp; Reports
#          </a>
# </li>
# <li>
# <a href="/dynamic/news/colloquium/">
#           Colloquium
#          </a>
# </li>
# <li>
# <a href="/home/research/seminars.html">
#           Seminars
#          </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/people/" id="nav-people" role="button">
#         People
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/dynamic/people/faculty/">
#           Faculty
#          </a>
# </li>
# <li>
# <a href="/dynamic/people/researchers/">
#           Researchers
#          </a>
# </li>
# <li>
# <a href="/dynamic/people/staff/">
#           Administration &amp; Staff
#          </a>
# </li>
# <li>
# <a href="/dynamic/people/phd_students/">
#           Ph.D. Students
#          </a>
# </li>
# <li>
# <a href="/home/people/alumni.html">
#           Alumni
#          </a>
# </li>
# <li>
# <a href="/home/people/in_memoriam.html">
#           In Memoriam
#          </a>
# </li>
# <li>
# <a href="https://cims.nyu.edu/webapps/directory/?hide_photos=1" target="_blank">
#           Courant Directory (login required)
#           <span aria-hidden="true" class="glyphicon glyphicon-new-window">
# </span>
# </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/undergrad/overview.html" id="nav-undergrad" role="button">
#         Undergraduates
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/home/undergrad/overview.html">
#           Overview
#          </a>
# </li>
# <li>
# <a href="/home/undergrad/cs_major.html">
#           CS Major
#          </a>
# </li>
# <li>
# <a href="/home/undergrad/minor_programs.html">
#           CS Minor
#          </a>
# </li>
# <li class="divider">
# </li>
# <li>
# <a href="/dynamic/calendar/undergraduate/">
#           Calendar
#          </a>
# </li>
# <li>
# <a href="/home/undergrad/resources.html">
#           Resources
#          </a>
# </li>
# <li>
# <a href="/home/undergrad/achievements.html">
#           Achievements
#          </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/master/prospective_overview.html" id="nav-master" role="button">
#         Masters
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/home/master/prospective_overview.html">
#           Prospective Students
#          </a>
# </li>
# <li>
# <a href="/home/master/incoming_overview.html">
#           Incoming Students
#          </a>
# </li>
# <li>
# <a href="/home/master/current_overview.html">
#           Current Students
#          </a>
# </li>
# <li class="divider">
# </li>
# <li>
# <a href="/dynamic/calendar/graduate/">
#           Calendar
#          </a>
# </li>
# <li>
# <a href="/home/master/resources.html">
#           Resources
#          </a>
# </li>
# <li>
# <a href="/dynamic/achievements/masters/">
#           Achievements
#          </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/phd/" id="nav-phd" role="button">
#         PH.D.
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/home/phd/index.html">
#           Overview
#          </a>
# </li>
# <li>
# <a href="/home/phd/admission.html">
#           Admissions
#          </a>
# </li>
# <li>
# <a href="/home/phd/degree_requirements.html">
#           Degree Requirements
#          </a>
# </li>
# <li class="divider">
# </li>
# <li>
# <a href="/dynamic/calendar/graduate/">
#           Calendar
#          </a>
# </li>
# <li>
# <a href="/home/phd/resources.html">
#           Resources
#          </a>
# </li>
# <li>
# <a href="/dynamic/achievements/phd/">
#           Achievements
#          </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/courses/" id="nav-courses" role="button">
#         Courses
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/dynamic/courses/catalog/">
#           Course Catalog
#          </a>
# </li>
# <li>
# <a href="/dynamic/courses/schedule/">
#           Course Schedule
#          </a>
# </li>
# <li>
# <a href="/dynamic/courses/exams/">
#           Exam Schedule
#          </a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a aria-expanded="false" href="/home/jobs/" id="nav-jobs" role="button">
#         Jobs
#        </a>
# <ul class="dropdown-menu">
# <li>
# <a href="/home/jobs/openings.html">
#           Job Openings
#          </a>
# </li>
# <li>
# <a href="/home/jobs/employers.html">
#           Prospective Employers
#          </a>
# </li>
# </ul>
# </li>
# <li>
# <a class="search" href="#" title="Search">
# <i class="fa fa-search">
# </i>
# </a>
# </li>
# </ul>
# <form action="https://search.nyu.edu/s/search.html" aria-label="Site Search" class="navbar-form" id="searchform" method="get" name="search" role="search" style="display: flex; flex-wrap: nowrap; align-items: center; justify-content: center;">
# <div class="form-group form-inline" style="white-space: nowrap;">
# <input name="collection" type="hidden" value="nyu-cs"/>
# <input name="profile" type="hidden" value="_default_preview"/>
# <div style="display: flex; flex-wrap: nowrap; flex-grow: 1; align-items: center; justify-content: center;">
# <div style="margin-bottom: 0;">
# <label for="search-cs" style="margin-bottom: 0;">
#           Search:
#          </label>
# </div>
# <div style="flex-grow: 1; padding-left: 10px;">
# <input class="form-control" id="search-cs" name="query" placeholder="Keyword" style="width: 100%;" type="text"/>
# </div>
# </div>
# </div>
# <div style="padding-left: 10px; display: flex; flex-wrap: nowrap; align-items: center; justify-content: center; margin-bottom: 1px;">
# <button class="btn btn-nyu-search" type="submit">
#         Submit
#        </button>
# </div>
# </form>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <!-- /.container-fluid -->
# </nav>
# </body>
# </html>
# </div>
# <!--[if lt IE 8]>
# <p class="browserupgrade">You are using an <strong>outdated</strong> browser. Please <a href="http://browsehappy.com/">upgrade
#     your browser</a> to improve your experience.</p>
# <![endif]-->
# <div id="wrap">
# <div id="main-content">
# </div>
# <h1 class="hidden-off-screen">
#     NYU Computer Science
#    </h1>
# <div class="container-fluid">
# <!-- Start Carousel -->
# <div class="carousel slide" data-interval="5000" data-ride="carousel" id="nyu-home-carousel">
# <!--start carousel -->
# <div class="carousel-inner">
# <!-- REMEMBER TO MAKE THE FIRST ITEM "ACTIVE" -->
# <!-- Welcome class of 2024. -->
# <!-- <div class="item active">
#                     <img src="images/carousel/Welcome2024-01.png" title="Welcome class of 2024">
#                 </div>
#                -->
# <!-- Welcome new faculty. -->
# <!--<div class="item active">
#        <img src="images/carousel/lerrel_pinto_2020-09-04.png" title="Welcome new faculty" alt="Welcome new faculty"/>
#        <div class="container">
#         <div class="carousel-caption">
#          <h2>
#           Welcome new faculty!
#          </h2>
#          <p>
#           Welcome to Lerrel Pinto, who is joining the department as assistant professor.
#          </p>
#         </div>
#        </div>
#       </div>-->
# <!-- Yann LeCun has been elected to the National Academy of Sciences -->
# <div class="item active">
# <img alt="Professor Yann LeCun" src="images/carousel/YannLeCunFacebookWindow-1200x450-c.jpg" title="Professor Yann LeCun"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#            National Academy of Sciences
#          </h2>
# <p>
#            Yann LeCun has been elected to the <a href="http://www.nasonline.org/news-and-multimedia/news/2021-nas-election.html">National Academy of Sciences</a>. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Chopra's as Associate Professor -->
# <div class="item">
# <img alt="Associate Professor Sumit Chopra" src="images/carousel/sumitChopra.jpg" title="Associate Professor Sumit Chopra"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Sumit Chopra is joining our department as Associate Professor. Welcome!
#          </h2>
# </div>
# </div>
# </div>
# <!-- Ted's NAE Membership -->
# <div class="item">
# <img alt="Professor Benjamin Peherstorfer" src="images/carousel/peherstorfer-01.jpg" title="Professor Benjamin Peherstorfer"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Benjamin Peherstorfer has been awarded an NSF Career award.
#          </h2>
# </div>
# </div>
# </div>
# <!-- Ted's NAE Membership -->
# <div class="item">
# <img alt="Professor Ted Rappaport" src="images/carousel/20190821-Rappaport-Ted.jpg" title="Professor Ted Rappaport"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           NAE Member
#          </h2>
# <p>
#           Ted Rappaport has been elected as Member of the
#            						National Academy of Engineering. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <div class="item">
# <img alt="Professor Patrick Cousot" src="images/carousel/patrick-cousot-IEEE-john-von-neumann-medal.jpg" title="Professor Patrick Cousot"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           2020 ACM Fellow
#          </h2>
# <p>
#           Patrick Cousot has been named a 2020 Fellow of the ACM, "for contributions to programming languages through the invention and development of abstract interpretation." Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Yann's Turing award. -->
# <div class="item">
# <img alt="Professor Yann LeCun" src="images/carousel/YannLeCunFacebookWindow-1200x450-c.jpg" title="Professor Yann LeCun"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Turing Award
#          </h2>
# <p>
#           Yann LeCun shares the 2018 Turing Award with Geoffrey Hinton and Yoshua Bengio,
#                                 "the fathers of the deep learning revolution." Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- International Collegiate Programming Contest-->
# <div class="item">
# <img alt="International Collegiate Programming Contest" src="images/carousel/programming_challenge.png" title="International Collegiate Programming Contest"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           International Collegiate Programming Contest
#          </h2>
# <p>
#           Muge Chen, Zhen Li, and Andy Polizzotto placed fifth in the inaugural North
#                                 America Championship of the International Collegiate Programming
#                                 Contest. They will advance to the World Finals in Moscow in June.
#                                 Congrats to them and their coach, Joanna Klukowska!
#          </p>
# </div>
# </div>
# </div>
# <!-- Daniele Panozzo Sloan Fellowship-->
# <div class="item">
# <img alt="Assistant Professor Daniele Panozzo" src="images/carousel/panozzo-nsf-career-award-alternate-20170302.jpg" title="Assistant Professor Daniele Panozzo"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Sloan Fellowship!
#          </h2>
# <p>
#           Daniele Panozzo has been awarded a Sloan
#                                 Fellowship for his work in solving partial differential equations on complex
#                                 geometrical domains. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Margaret's von Neumann Prize -->
# <div class="item">
# <img alt="Professor Margaret Wright" src="images/carousel/margaret-wright-1200x450.jpg" title="Professor Margaret Wright"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           John von Neumann Prize
#          </h2>
# <p>
#           Margaret Wright has been awarded the 2019 John von Neumann Prize by SIAM
#                                 (Society of Industrial and Applied Mathematics). Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Yann's Legion of Honor -->
# <div class="item">
# <img alt="Professor Yann LeCun" src="images/carousel/YannLeCunFacebookWindow-1200x450-c.jpg" title="Professor Yann LeCun"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Legion of Honor
#          </h2>
# <p>
#           Yann LeCun has been named a Knight of the Legion of Honor. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Ted's Sumner Award -->
# <div class="item">
# <img alt="Professor Ted Rappaport" src="images/carousel/20190821-Rappaport-Ted.jpg" title="Professor Ted Rappaport"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Eric E. Sumner Award
#          </h2>
# <p>
#           IEEE has awarded the 2020 Eric E. Sumner Award to Ted Rappaport "for pioneering
#                                 contributions to radio channel modeling and characterization,
#                                 and millimeter wave communication systems." Ted has also been named to the Wireless Hall
#                                 of Fame. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Oded's Godel Prize -->
# <div class="item">
# <img alt="Professor Oded Regev" src="images/carousel/20180308-oded-regev-godel-prize.jpg" title="Professor Oded Regev"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Gödel Prize and Simons Investigator
#          </h2>
# <p>
#           Oded Regev has been awarded the 2018 Gödel Prize for his 2005 paper, "On
#                                 lattices, learning with errors, random linear codes, and cryptography."
#                                 He has also been named a 2019 Simons Investigator for his work in lattice-based
#                                 cryptography. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Marsha's Norbert Weiner Prize -->
# <div class="item">
# <img alt="Professor Marsha Berger" src="images/carousel/marsha-berger-norbert-wiener-prize.jpg" title="Professor Marsha Berger"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Norbert Wiener Prize
#          </h2>
# <p>
#           Marsha Berger has been awarded the American Mathematical
#                                 Society Norbert Wiener Prize. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Chee's Academia Europaea -->
# <div class="item">
# <img alt="Professor Chee Yap" src="images/carousel/20190821-chee-yap-prize-bigger.jpg" title="Professor Chee Yap"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Academia Europaea
#          </h2>
# <p>
#           Chee Yap has been elected to Academia Europaea.
#                                 Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Denis' SIGGRAPH award -->
# <div class="item">
# <img alt="Professor Denis Zorin" src="images/carousel/denis-zorin-1200x450.jpg" title="Professor Denis Zorin"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           ACM SIGGRAPH Computer Graphics Achievement Award
#          </h2>
# <p>
#           Silver Professor Denis Zorin has received the 2019 Computer Graphics
#                                 Achievement Award "in recognition of his fundamental contributions to computer
#                                 graphics and geometric modeling." Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Joan's CAREER award -->
# <div class="item">
# <img alt="Professor Joan Bruna" src="images/carousel/bruna_joan_20160908.jpg" title="Professor Joan Bruna"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           NSF CAREER Award
#          </h2>
# <p>
#           Joan Bruna has been awarded an NSF CAREER Award for his
#                                 proposal, "Theory and Applications of Geometric Deep Learning."
#                                 Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Julia's Academia Europaea -->
# <div class="item">
# <img alt="Professor Julia Kempe" src="images/carousel/julia-kempe-1200x450.jpg" title="Professor Julia Kempe"/>
# <div class="container">
# <div class="carousel-caption">
# <h2>
#           Academia Europaea
#          </h2>
# <p>
#           Julia Kempe has been elected as a member of the
#                                 Academia Europaea. Congratulations!
#          </p>
# </div>
# </div>
# </div>
# <!-- Students -->
# <!--
# 					<div class="item">
#                       <img alt="Left to Right: Alex Wang, Zhongshi Jiang, Ananditha Raghunath, Noah Stephens-Davidowitz"
#                            src="images/carousel/students.jpg"
#                            title="Recognition for our Students">
#                       <div class="container">
#                           <div class="carousel-caption">
#                               <h2>Recognition for our Students</h2>
#                               <p>
#                                   Our students have won an NSF Graduate Research Fellowship, an Adobe Research
#                                   Fellowship, an NYU Presidential Service Award, and a GSAS Outstanding
#                                   Dissertation Award<br/>(L to R: Alex Wang, Zhongshi Jiang, Ananditha
#                                   Raghunath, Noah Stephens-Davidowitz)
#                               </p>
#                           </div>
#                       </div>
#                   </div>
# 				-->
# </div>
# <!-- End Carousel Slides -->
# <a class="left carousel-control" data-slide="prev" href="#nyu-home-carousel">
# <img alt="previous slide" src="/home/images/arrow-left.png"/>
# </a>
# <a class="right carousel-control" data-slide="next" href="#nyu-home-carousel">
# <img alt="next slide" src="/home/images/arrow-right.png"/>
# </a>
# <ol class="carousel-indicators">
# <li class="active" data-slide-to="0" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="1" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="2" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="3" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="4" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="5" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="6" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="7" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="8" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="9" data-target="#nyu-home-carousel">
# </li>
# <li class="" data-slide-to="10" data-target="#nyu-home-carousel">
# </li>
# </ol>
# </div>
# <!-- End Carousel -->
# </div>
# <!-- End container-fluid -->
# <div class="container-fluid home">
# <!-- Example row of columns -->
# <div class="row">
# <div class="col-md-3 col-sm-3">
# <h2 class="heading-with-bg">
#        Research
#       </h2>
# <ul class="research-areas">
# <li>
# <h3>
#          Areas
#         </h3>
# </li>
# <li>
# <a href="/dynamic/research/areas/#theory">
#          Algorithms / Theory
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#biology">
#          Computational Biology
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#verification">
#          Formal Methods and Verification
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#graphics_vision_and_ui">
#          Graphics / Vision / User
#                         Interfaces
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#learning">
#          Machine Learning
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#nlp">
#          Natural Language Processing
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#sci">
#          Scientific Computing
#         </a>
# </li>
# <li>
# <a href="/dynamic/research/areas/#systems">
#          Systems / Networking
#         </a>
# </li>
# </ul>
# <ul class="research-centers">
# <li>
# <h3>
#          Centers
#         </h3>
# </li>
# <li>
# <a href="http://cds.nyu.edu">
#          Data Science
#         </a>
# </li>
# <li>
# <a href="http://magnet.nyu.edu">
#          Media and Games Network
#         </a>
# </li>
# <li>
# <a href="http://www.nyucted.org/">
#          Technology Development &amp; Economics
#         </a>
# </li>
# <li>
# <a href="http://as.nyu.edu/biology/research/gsb.html">
#          Genomics &amp; Systems Biology
#         </a>
# </li>
# <li>
# <a href="http://wireless.engineering.nyu.edu">
#          NYU Wireless
#         </a>
# </li>
# </ul>
# </div>
# <div class="col-md-6 col-sm-5">
# <div class="border-left border-right">
# <h2 class="heading-with-bg">
#         News &amp; Highlights
#        </h2>
# <!--include virtual="/dynamic/news/short_list/" -->
# <div id="news">
# </div>
# <p>
# <a class="btn btn-nyu" href="/dynamic/news/" role="button">
#          More News
#         </a>
# </p>
# </div>
# </div>
# <div class="col-md-3 col-sm-4">
# <h2 class="heading-with-bg">
#        Events
#       </h2>
# <div id="events">
# </div>
# <p>
# <a class="btn btn-nyu back-left" href="/dynamic/news/event/" role="button">
#         View Full Calendar
#        </a>
# </p>
# </div>
# </div>
# </div>
# <!-- /container -->
# <footer>
# <div class="col-sm-7 col-xs-12">
# <p style="color: #707070; font-size: 14px;">
#             Computer Science Department at New York University<br/>
#             Warren Weaver Hall, Room 305<br/>
#             251 Mercer Street, New York, NY 10012<br/>
# <strong><a href="/home/about/contacts.html" style="color: #707070; font-size: 14px;">Contact Us</a></strong>
# </p>
# </div>
# <div class="col-sm-5 col-xs-12 text-right">
# <p class="nyu-links">
# <a href="http://cims.nyu.edu/" style="color: #707070; font-size: 14px;">NYU Courant Institute of Mathematical Sciences</a><br/>
# <a href="http://gsas.nyu.edu/" style="color: #707070; font-size: 14px;">NYU Graduate School of Arts &amp; Science</a><br/>
# <a href="http://cas.nyu.edu/" style="color: #707070; font-size: 14px;">NYU College of Arts &amp; Science</a><br/>
# <strong><a href="http://www.nyu.edu/accessibility" style="color: #707070; font-size: 14px;">Accessibility</a></strong>
# </p>
# </div>
# </footer>
# </div>
# <!-- Scripts -->
# <script>
#    window.jQuery || document.write('<script src="js/vendor/jquery-1.11.2.min.js"><\/script>')
#   </script>
# <script src="js/vendor/bootstrap.min.js">
# </script>
# <script src="js/main.js">
# </script>
# <!-- Google Analytics -->
# <script>
#    (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-63794280-2', 'auto');
#     ga('send', 'pageview');
#   </script>
# </body>
# </html>

# %%
# we can extract the title of the document

soup.title
soup.title.string
# Out:
# '\n   NYU Computer Science\n  '

# %%
# we can extract the first paragraph 

soup.p

# open link in the browser, right click and "page source". Can you find <p> tags?
# and hyperlinks
# Out:
# <p>
#            Yann LeCun has been elected to the <a href="http://www.nasonline.org/news-and-multimedia/news/2021-nas-election.html">National Academy of Sciences</a>. Congratulations!
#          </p>

# %%
# Grab all the links

all_links  = soup.find_all('a')
all_links
#type(all_links)
# Out:
# [<a href="#main-content" id="skiptomaincontent">
#        Skip to main content
#       </a>,
#  <a href="https://www.nyu.edu/life/safety-health-wellness/coronavirus-information.html" style="color: #545157;">COVID-19 INFO</a>,
#  <a href="https://cs.nyu.edu/home/courses/grad-fall21.html">
#          Graduate
#         </a>,
#  <a href="https://cs.nyu.edu/home/courses/ug-fall21.html">
#          Undergraduate
#         </a>,
#  <a href="http://www.nyu.edu">
#           NYU
#          </a>,
#  <a href="http://cims.nyu.edu">
#          COURANT
#         </a>,
#  <a href="/">
#           Computer Science
#          </a>,
#  <a aria-expanded="false" href="/home/about/" id="nav-about" role="button">
#          About
#         </a>,
#  <a href="/dynamic/news/">
#            News &amp; Events
#           </a>,
#  <a href="/home/about/directions.html">
#            Directions
#           </a>,
#  <a href="/home/about/contacts.html">
#            Contacts
#           </a>,
#  <a aria-expanded="false" href="/home/research/overview.html" id="nav-research" role="button">
#          Research
#         </a>,
#  <a href="/home/research/overview.html">
#            Overview
#           </a>,
#  <a href="/home/research/centers.html">
#            Centers
#           </a>,
#  <a href="/dynamic/research/areas/">
#            Areas
#           </a>,
#  <a href="/dynamic/people/achievements/">
#            Faculty Achievements
#           </a>,
#  <a href="/dynamic/reports/">
#            Theses &amp; Reports
#           </a>,
#  <a href="/dynamic/news/colloquium/">
#            Colloquium
#           </a>,
#  <a href="/home/research/seminars.html">
#            Seminars
#           </a>,
#  <a aria-expanded="false" href="/home/people/" id="nav-people" role="button">
#          People
#         </a>,
#  <a href="/dynamic/people/faculty/">
#            Faculty
#           </a>,
#  <a href="/dynamic/people/researchers/">
#            Researchers
#           </a>,
#  <a href="/dynamic/people/staff/">
#            Administration &amp; Staff
#           </a>,
#  <a href="/dynamic/people/phd_students/">
#            Ph.D. Students
#           </a>,
#  <a href="/home/people/alumni.html">
#            Alumni
#           </a>,
#  <a href="/home/people/in_memoriam.html">
#            In Memoriam
#           </a>,
#  <a href="https://cims.nyu.edu/webapps/directory/?hide_photos=1" target="_blank">
#            Courant Directory (login required)
#            <span aria-hidden="true" class="glyphicon glyphicon-new-window">
#  </span>
#  </a>,
#  <a aria-expanded="false" href="/home/undergrad/overview.html" id="nav-undergrad" role="button">
#          Undergraduates
#         </a>,
#  <a href="/home/undergrad/overview.html">
#            Overview
#           </a>,
#  <a href="/home/undergrad/cs_major.html">
#            CS Major
#           </a>,
#  <a href="/home/undergrad/minor_programs.html">
#            CS Minor
#           </a>,
#  <a href="/dynamic/calendar/undergraduate/">
#            Calendar
#           </a>,
#  <a href="/home/undergrad/resources.html">
#            Resources
#           </a>,
#  <a href="/home/undergrad/achievements.html">
#            Achievements
#           </a>,
#  <a aria-expanded="false" href="/home/master/prospective_overview.html" id="nav-master" role="button">
#          Masters
#         </a>,
#  <a href="/home/master/prospective_overview.html">
#            Prospective Students
#           </a>,
#  <a href="/home/master/incoming_overview.html">
#            Incoming Students
#           </a>,
#  <a href="/home/master/current_overview.html">
#            Current Students
#           </a>,
#  <a href="/dynamic/calendar/graduate/">
#            Calendar
#           </a>,
#  <a href="/home/master/resources.html">
#            Resources
#           </a>,
#  <a href="/dynamic/achievements/masters/">
#            Achievements
#           </a>,
#  <a aria-expanded="false" href="/home/phd/" id="nav-phd" role="button">
#          PH.D.
#         </a>,
#  <a href="/home/phd/index.html">
#            Overview
#           </a>,
#  <a href="/home/phd/admission.html">
#            Admissions
#           </a>,
#  <a href="/home/phd/degree_requirements.html">
#            Degree Requirements
#           </a>,
#  <a href="/dynamic/calendar/graduate/">
#            Calendar
#           </a>,
#  <a href="/home/phd/resources.html">
#            Resources
#           </a>,
#  <a href="/dynamic/achievements/phd/">
#            Achievements
#           </a>,
#  <a aria-expanded="false" href="/home/courses/" id="nav-courses" role="button">
#          Courses
#         </a>,
#  <a href="/dynamic/courses/catalog/">
#            Course Catalog
#           </a>,
#  <a href="/dynamic/courses/schedule/">
#            Course Schedule
#           </a>,
#  <a href="/dynamic/courses/exams/">
#            Exam Schedule
#           </a>,
#  <a aria-expanded="false" href="/home/jobs/" id="nav-jobs" role="button">
#          Jobs
#         </a>,
#  <a href="/home/jobs/openings.html">
#            Job Openings
#           </a>,
#  <a href="/home/jobs/employers.html">
#            Prospective Employers
#           </a>,
#  <a class="search" href="#" title="Search">
#  <i class="fa fa-search">
#  </i>
#  </a>,
#  <a href="http://www.nasonline.org/news-and-multimedia/news/2021-nas-election.html">National Academy of Sciences</a>,
#  <a class="left carousel-control" data-slide="prev" href="#nyu-home-carousel">
#  <img alt="previous slide" src="/home/images/arrow-left.png"/>
#  </a>,
#  <a class="right carousel-control" data-slide="next" href="#nyu-home-carousel">
#  <img alt="next slide" src="/home/images/arrow-right.png"/>
#  </a>,
#  <a href="/dynamic/research/areas/#theory">
#           Algorithms / Theory
#          </a>,
#  <a href="/dynamic/research/areas/#biology">
#           Computational Biology
#          </a>,
#  <a href="/dynamic/research/areas/#verification">
#           Formal Methods and Verification
#          </a>,
#  <a href="/dynamic/research/areas/#graphics_vision_and_ui">
#           Graphics / Vision / User
#                          Interfaces
#          </a>,
#  <a href="/dynamic/research/areas/#learning">
#           Machine Learning
#          </a>,
#  <a href="/dynamic/research/areas/#nlp">
#           Natural Language Processing
#          </a>,
#  <a href="/dynamic/research/areas/#sci">
#           Scientific Computing
#          </a>,
#  <a href="/dynamic/research/areas/#systems">
#           Systems / Networking
#          </a>,
#  <a href="http://cds.nyu.edu">
#           Data Science
#          </a>,
#  <a href="http://magnet.nyu.edu">
#           Media and Games Network
#          </a>,
#  <a href="http://www.nyucted.org/">
#           Technology Development &amp; Economics
#          </a>,
#  <a href="http://as.nyu.edu/biology/research/gsb.html">
#           Genomics &amp; Systems Biology
#          </a>,
#  <a href="http://wireless.engineering.nyu.edu">
#           NYU Wireless
#          </a>,
#  <a class="btn btn-nyu" href="/dynamic/news/" role="button">
#           More News
#          </a>,
#  <a class="btn btn-nyu back-left" href="/dynamic/news/event/" role="button">
#          View Full Calendar
#         </a>,
#  <a href="/home/about/contacts.html" style="color: #707070; font-size: 14px;">Contact Us</a>,
#  <a href="http://cims.nyu.edu/" style="color: #707070; font-size: 14px;">NYU Courant Institute of Mathematical Sciences</a>,
#  <a href="http://gsas.nyu.edu/" style="color: #707070; font-size: 14px;">NYU Graduate School of Arts &amp; Science</a>,
#  <a href="http://cas.nyu.edu/" style="color: #707070; font-size: 14px;">NYU College of Arts &amp; Science</a>,
#  <a href="http://www.nyu.edu/accessibility" style="color: #707070; font-size: 14px;">Accessibility</a>]

# %%
# print all the links
for link in soup.find_all('a'):
    print("new link: " + link.text+ "\n")
# Out:
# new link:
#       Skip to main content
#
#
# new link: COVID-19 INFO
#
# new link:
#         Graduate
#
#
# new link:
#         Undergraduate
#
#
# new link:
#          NYU
#
#
# new link:
#         COURANT
#
#
# new link:
#          Computer Science
#
#
# new link:
#         About
#
#
# new link:
#           News & Events
#
#
# new link:
#           Directions
#
#
# new link:
#           Contacts
#
#
# new link:
#         Research
#
#
# new link:
#           Overview
#
#
# new link:
#           Centers
#
#
# new link:
#           Areas
#
#
# new link:
#           Faculty Achievements
#
#
# new link:
#           Theses & Reports
#
#
# new link:
#           Colloquium
#
#
# new link:
#           Seminars
#
#
# new link:
#         People
#
#
# new link:
#           Faculty
#
#
# new link:
#           Researchers
#
#
# new link:
#           Administration & Staff
#
#
# new link:
#           Ph.D. Students
#
#
# new link:
#           Alumni
#
#
# new link:
#           In Memoriam
#
#
# new link:
#           Courant Directory (login required)
#
#
#
#
# new link:
#         Undergraduates
#
#
# new link:
#           Overview
#
#
# new link:
#           CS Major
#
#
# new link:
#           CS Minor
#
#
# new link:
#           Calendar
#
#
# new link:
#           Resources
#
#
# new link:
#           Achievements
#
#
# new link:
#         Masters
#
#
# new link:
#           Prospective Students
#
#
# new link:
#           Incoming Students
#
#
# new link:
#           Current Students
#
#
# new link:
#           Calendar
#
#
# new link:
#           Resources
#
#
# new link:
#           Achievements
#
#
# new link:
#         PH.D.
#
#
# new link:
#           Overview
#
#
# new link:
#           Admissions
#
#
# new link:
#           Degree Requirements
#
#
# new link:
#           Calendar
#
#
# new link:
#           Resources
#
#
# new link:
#           Achievements
#
#
# new link:
#         Courses
#
#
# new link:
#           Course Catalog
#
#
# new link:
#           Course Schedule
#
#
# new link:
#           Exam Schedule
#
#
# new link:
#         Jobs
#
#
# new link:
#           Job Openings
#
#
# new link:
#           Prospective Employers
#
#
# new link:
#
#
#
#
# new link: National Academy of Sciences
#
# new link:
#
#
#
# new link:
#
#
#
# new link:
#          Algorithms / Theory
#
#
# new link:
#          Computational Biology
#
#
# new link:
#          Formal Methods and Verification
#
#
# new link:
#          Graphics / Vision / User
#                         Interfaces
#
#
# new link:
#          Machine Learning
#
#
# new link:
#          Natural Language Processing
#
#
# new link:
#          Scientific Computing
#
#
# new link:
#          Systems / Networking
#
#
# new link:
#          Data Science
#
#
# new link:
#          Media and Games Network
#
#
# new link:
#          Technology Development & Economics
#
#
# new link:
#          Genomics & Systems Biology
#
#
# new link:
#          NYU Wireless
#
#
# new link:
#          More News
#
#
# new link:
#         View Full Calendar
#
#
# new link: Contact Us
#
# new link: NYU Courant Institute of Mathematical Sciences
#
# new link: NYU Graduate School of Arts & Science
#
# new link: NYU College of Arts & Science
#
# new link: Accessibility

# %%
for link in soup.find_all('a'):
    print("new link: " + str(link.get('href'))+ "\n")
# Out:
# new link: #main-content
#
# new link: https://www.nyu.edu/life/safety-health-wellness/coronavirus-information.html
#
# new link: https://cs.nyu.edu/home/courses/grad-fall21.html
#
# new link: https://cs.nyu.edu/home/courses/ug-fall21.html
#
# new link: http://www.nyu.edu
#
# new link: http://cims.nyu.edu
#
# new link: /
#
# new link: /home/about/
#
# new link: /dynamic/news/
#
# new link: /home/about/directions.html
#
# new link: /home/about/contacts.html
#
# new link: /home/research/overview.html
#
# new link: /home/research/overview.html
#
# new link: /home/research/centers.html
#
# new link: /dynamic/research/areas/
#
# new link: /dynamic/people/achievements/
#
# new link: /dynamic/reports/
#
# new link: /dynamic/news/colloquium/
#
# new link: /home/research/seminars.html
#
# new link: /home/people/
#
# new link: /dynamic/people/faculty/
#
# new link: /dynamic/people/researchers/
#
# new link: /dynamic/people/staff/
#
# new link: /dynamic/people/phd_students/
#
# new link: /home/people/alumni.html
#
# new link: /home/people/in_memoriam.html
#
# new link: https://cims.nyu.edu/webapps/directory/?hide_photos=1
#
# new link: /home/undergrad/overview.html
#
# new link: /home/undergrad/overview.html
#
# new link: /home/undergrad/cs_major.html
#
# new link: /home/undergrad/minor_programs.html
#
# new link: /dynamic/calendar/undergraduate/
#
# new link: /home/undergrad/resources.html
#
# new link: /home/undergrad/achievements.html
#
# new link: /home/master/prospective_overview.html
#
# new link: /home/master/prospective_overview.html
#
# new link: /home/master/incoming_overview.html
#
# new link: /home/master/current_overview.html
#
# new link: /dynamic/calendar/graduate/
#
# new link: /home/master/resources.html
#
# new link: /dynamic/achievements/masters/
#
# new link: /home/phd/
#
# new link: /home/phd/index.html
#
# new link: /home/phd/admission.html
#
# new link: /home/phd/degree_requirements.html
#
# new link: /dynamic/calendar/graduate/
#
# new link: /home/phd/resources.html
#
# new link: /dynamic/achievements/phd/
#
# new link: /home/courses/
#
# new link: /dynamic/courses/catalog/
#
# new link: /dynamic/courses/schedule/
#
# new link: /dynamic/courses/exams/
#
# new link: /home/jobs/
#
# new link: /home/jobs/openings.html
#
# new link: /home/jobs/employers.html
#
# new link: #
#
# new link: http://www.nasonline.org/news-and-multimedia/news/2021-nas-election.html
#
# new link: #nyu-home-carousel
#
# new link: #nyu-home-carousel
#
# new link: /dynamic/research/areas/#theory
#
# new link: /dynamic/research/areas/#biology
#
# new link: /dynamic/research/areas/#verification
#
# new link: /dynamic/research/areas/#graphics_vision_and_ui
#
# new link: /dynamic/research/areas/#learning
#
# new link: /dynamic/research/areas/#nlp
#
# new link: /dynamic/research/areas/#sci
#
# new link: /dynamic/research/areas/#systems
#
# new link: http://cds.nyu.edu
#
# new link: http://magnet.nyu.edu
#
# new link: http://www.nyucted.org/
#
# new link: http://as.nyu.edu/biology/research/gsb.html
#
# new link: http://wireless.engineering.nyu.edu
#
# new link: /dynamic/news/
#
# new link: /dynamic/news/event/
#
# new link: /home/about/contacts.html
#
# new link: http://cims.nyu.edu/
#
# new link: http://gsas.nyu.edu/
#
# new link: http://cas.nyu.edu/
#
# new link: http://www.nyu.edu/accessibility

# %%
# Show the text
print(soup.get_text())
# Out:
#    NYU Computer Science
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#    $(function () {
#             $("#news").load("/dynamic/news/short_list/");
#         });
#         $(function () {
#             $("#events").load("/dynamic/news/event/short_list/");
#         });
#
#
#
#
#
#
#
#
#
#
#
#
#
#       Skip to main content
#
#
#
# COVID-19 INFO | Fall 2021 Schedule Information:
#
#         Graduate
#
#        /
#
#         Undergraduate
#
#
#
#
#
#
#
#          NYU
#
#
#
#         |
#
#
#         COURANT
#
#
#
#
#
#
#
#
#          Computer Science
#
#
#
#
#
#
#        Toggle navigation
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         About
#
#
#
#
#           News & Events
#
#
#
#
#           Directions
#
#
#
#
#           Contacts
#
#
#
#
#
#
#         Research
#
#
#
#
#           Overview
#
#
#
#
#           Centers
#
#
#
#
#           Areas
#
#
#
#
#           Faculty Achievements
#
#
#
#
#           Theses & Reports
#
#
#
#
#           Colloquium
#
#
#
#
#           Seminars
#
#
#
#
#
#
#         People
#
#
#
#
#           Faculty
#
#
#
#
#           Researchers
#
#
#
#
#           Administration & Staff
#
#
#
#
#           Ph.D. Students
#
#
#
#
#           Alumni
#
#
#
#
#           In Memoriam
#
#
#
#
#           Courant Directory (login required)
#
#
#
#
#
#
#
#
#         Undergraduates
#
#
#
#
#           Overview
#
#
#
#
#           CS Major
#
#
#
#
#           CS Minor
#
#
#
#
#
#
#           Calendar
#
#
#
#
#           Resources
#
#
#
#
#           Achievements
#
#
#
#
#
#
#         Masters
#
#
#
#
#           Prospective Students
#
#
#
#
#           Incoming Students
#
#
#
#
#           Current Students
#
#
#
#
#
#
#           Calendar
#
#
#
#
#           Resources
#
#
#
#
#           Achievements
#
#
#
#
#
#
#         PH.D.
#
#
#
#
#           Overview
#
#
#
#
#           Admissions
#
#
#
#
#           Degree Requirements
#
#
#
#
#
#
#           Calendar
#
#
#
#
#           Resources
#
#
#
#
#           Achievements
#
#
#
#
#
#
#         Courses
#
#
#
#
#           Course Catalog
#
#
#
#
#           Course Schedule
#
#
#
#
#           Exam Schedule
#
#
#
#
#
#
#         Jobs
#
#
#
#
#           Job Openings
#
#
#
#
#           Prospective Employers
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Search:
#
#
#
#
#
#
#
#
#
#         Submit
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     NYU Computer Science
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#            National Academy of Sciences
#
#
#            Yann LeCun has been elected to the National Academy of Sciences. Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Sumit Chopra is joining our department as Associate Professor. Welcome!
#
#
#
#
#
#
#
#
#
#
#           Benjamin Peherstorfer has been awarded an NSF Career award.
#
#
#
#
#
#
#
#
#
#
#           NAE Member
#
#
#           Ted Rappaport has been elected as Member of the
#            						National Academy of Engineering. Congratulations!
#
#
#
#
#
#
#
#
#
#           2020 ACM Fellow
#
#
#           Patrick Cousot has been named a 2020 Fellow of the ACM, "for contributions to programming languages through the invention and development of abstract interpretation." Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Turing Award
#
#
#           Yann LeCun shares the 2018 Turing Award with Geoffrey Hinton and Yoshua Bengio,
#                                 "the fathers of the deep learning revolution." Congratulations!
#
#
#
#
#
#
#
#
#
#
#           International Collegiate Programming Contest
#
#
#           Muge Chen, Zhen Li, and Andy Polizzotto placed fifth in the inaugural North
#                                 America Championship of the International Collegiate Programming
#                                 Contest. They will advance to the World Finals in Moscow in June.
#                                 Congrats to them and their coach, Joanna Klukowska!
#
#
#
#
#
#
#
#
#
#
#           Sloan Fellowship!
#
#
#           Daniele Panozzo has been awarded a Sloan
#                                 Fellowship for his work in solving partial differential equations on complex
#                                 geometrical domains. Congratulations!
#
#
#
#
#
#
#
#
#
#
#           John von Neumann Prize
#
#
#           Margaret Wright has been awarded the 2019 John von Neumann Prize by SIAM
#                                 (Society of Industrial and Applied Mathematics). Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Legion of Honor
#
#
#           Yann LeCun has been named a Knight of the Legion of Honor. Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Eric E. Sumner Award
#
#
#           IEEE has awarded the 2020 Eric E. Sumner Award to Ted Rappaport "for pioneering
#                                 contributions to radio channel modeling and characterization,
#                                 and millimeter wave communication systems." Ted has also been named to the Wireless Hall
#                                 of Fame. Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Gödel Prize and Simons Investigator
#
#
#           Oded Regev has been awarded the 2018 Gödel Prize for his 2005 paper, "On
#                                 lattices, learning with errors, random linear codes, and cryptography."
#                                 He has also been named a 2019 Simons Investigator for his work in lattice-based
#                                 cryptography. Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Norbert Wiener Prize
#
#
#           Marsha Berger has been awarded the American Mathematical
#                                 Society Norbert Wiener Prize. Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Academia Europaea
#
#
#           Chee Yap has been elected to Academia Europaea.
#                                 Congratulations!
#
#
#
#
#
#
#
#
#
#
#           ACM SIGGRAPH Computer Graphics Achievement Award
#
#
#           Silver Professor Denis Zorin has received the 2019 Computer Graphics
#                                 Achievement Award "in recognition of his fundamental contributions to computer
#                                 graphics and geometric modeling." Congratulations!
#
#
#
#
#
#
#
#
#
#
#           NSF CAREER Award
#
#
#           Joan Bruna has been awarded an NSF CAREER Award for his
#                                 proposal, "Theory and Applications of Geometric Deep Learning."
#                                 Congratulations!
#
#
#
#
#
#
#
#
#
#
#           Academia Europaea
#
#
#           Julia Kempe has been elected as a member of the
#                                 Academia Europaea. Congratulations!
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#        Research
#
#
#
#
#          Areas
#
#
#
#
#          Algorithms / Theory
#
#
#
#
#          Computational Biology
#
#
#
#
#          Formal Methods and Verification
#
#
#
#
#          Graphics / Vision / User
#                         Interfaces
#
#
#
#
#          Machine Learning
#
#
#
#
#          Natural Language Processing
#
#
#
#
#          Scientific Computing
#
#
#
#
#          Systems / Networking
#
#
#
#
#
#
#          Centers
#
#
#
#
#          Data Science
#
#
#
#
#          Media and Games Network
#
#
#
#
#          Technology Development & Economics
#
#
#
#
#          Genomics & Systems Biology
#
#
#
#
#          NYU Wireless
#
#
#
#
#
#
#
#         News & Highlights
#
#
#
#
#
#
#          More News
#
#
#
#
#
#
#        Events
#
#
#
#
#
#         View Full Calendar
#
#
#
#
#
#
#
#
#
#             Computer Science Department at New York University
#             Warren Weaver Hall, Room 305
#             251 Mercer Street, New York, NY 10012
# Contact Us
#
#
#
#
# NYU Courant Institute of Mathematical Sciences
# NYU Graduate School of Arts & Science
# NYU College of Arts & Science
# Accessibility
#
#
#
#
#
#
#    window.jQuery || document.write('<script src="js/vendor/jquery-1.11.2.min.js"><\/script>')
#
#
#
#
#
#
#
#    (function (i, s, o, g, r, a, m) {
#         i['GoogleAnalyticsObject'] = r;
#         i[r] = i[r] || function () {
#             (i[r].q = i[r].q || []).push(arguments)
#         }, i[r].l = 1 * new Date();
#         a = s.createElement(o),
#             m = s.getElementsByTagName(o)[0];
#         a.async = 1;
#         a.src = g;
#         m.parentNode.insertBefore(a, m)
#     })(window, document, 'script', '//www.google-analytics.com/analytics.js', 'ga');
#
#     ga('create', 'UA-63794280-2', 'auto');
#     ga('send', 'pageview');
